# %%
library(tidyverse)
library(repr)
library(tidymodels)
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.0 ──
#
# ✔ ggplot2 3.3.2     ✔ purrr   0.3.4
# ✔ tibble  3.0.3     ✔ dplyr   1.0.2
# ✔ tidyr   1.1.2     ✔ stringr 1.4.0
# ✔ readr   1.3.1     ✔ forcats 0.5.0
#
# Warning message:
# “package ‘ggplot2’ was built under R version 4.0.1”
# Warning message:
# “package ‘tibble’ was built under R version 4.0.2”
# Warning message:
# “package ‘tidyr’ was built under R version 4.0.2”
# Warning message:
# “package ‘dplyr’ was built under R version 4.0.2”
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
#
# Warning message:
# “package ‘tidymodels’ was built under R version 4.0.2”
# ── Attaching packages ────────────────────────────────────── tidymodels 0.1.1 ──
#
# ✔ broom     0.7.0      ✔ recipes   0.1.13
# ✔ dials     0.0.9      ✔ rsample   0.0.7
# ✔ infer     0.5.4      ✔ tune      0.1.1
# ✔ modeldata 0.0.2      ✔ workflows 0.2.0
# ✔ parsnip   0.1.3      ✔ yardstick 0.0.7
#
# Warning message:
# “package ‘broom’ was built under R version 4.0.2”
# Warning message:
# “package ‘dials’ was built under R version 4.0.2”
# Warning message:
# “package ‘infer’ was built under R version 4.0.3”
# Warning message:
# “package ‘modeldata’ was built under R version 4.0.1”
# Warning message:
# “package ‘parsnip’ was built under R version 4.0.2”
# Warning message:
# “package ‘recipes’ was built under R version 4.0.1”
# Warning message:
# “package ‘tune’ was built under R version 4.0.2”
# Warning message:
# “package ‘workflows’ was built under R version 4.0.2”
# Warning message:
# “package ‘yardstick’ was built under R version 4.0.2”
# ── Conflicts ───────────────────────────────────────── tidymodels_conflicts() ──
# ✖ scales::discard() masks purrr::discard()
# ✖ dplyr::filter()   masks stats::filter()
# ✖ recipes::fixed()  masks stringr::fixed()
# ✖ dplyr::lag()      masks stats::lag()
# ✖ yardstick::spec() masks readr::spec()
# ✖ recipes::step()   masks stats::step()

# %%
data <- read_csv("https://docs.google.com/spreadsheets/d/e/2PACX-1vSTyupJYW8-dOI7rTKOVE-bMT4M_8UnVnRLOJGavyVh33-4wHTkP4Q-uWX9mwMQul2kxMl8aJLR0FHB/pub?output=csv")
# Out:
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   url = col_character()
# )
#
# See spec(...) for full column specifications.

# %%
named_data <- data %>%
    rename(
        monday = weekday_is_monday,
        tuesday = weekday_is_tuesday,
        wednesday = weekday_is_wednesday,
        thursday = weekday_is_thursday,
        friday = weekday_is_friday,
        saturday = weekday_is_saturday,
        sunday = weekday_is_sunday,
        lifestyle = data_channel_is_lifestyle,
        entertainment =  data_channel_is_entertainment,
        business = data_channel_is_bus,
        society_and_medicine =  data_channel_is_socmed,
        technology =  data_channel_is_tech,
        world =  data_channel_is_world,
    )

# %%
#It didn't work when all in one pipe, I have no idea why. This seems to work though
tidy_data <- named_data %>%
    pivot_longer(cols =  lifestyle:world, 
                 names_to = 'Genre', 
                 values_to = 'Genre_Present') %>%
    filter(Genre_Present == 1) %>%
    pivot_longer(cols =   monday:sunday, 
                 names_to = 'Day_Of_Week', 
                 values_to = 'Day_Present') %>%
    filter(Day_Present == 1) %>%
    mutate(Genre = as_factor(Genre)) %>%
    mutate(Day_Of_Week = as_factor(Day_Of_Week))%>%
    mutate (Popular = shares > 1000)%>%
    mutate(Popular = as_factor(Popular)) %>%
    mutate(Unpopular = shares <999)%>%
    mutate(Unpopular = as_factor(Unpopular)) %>%
    select(Genre, Day_Of_Week, shares, Popular, num_keywords, n_unique_tokens)

head(tidy_data)
nrow(tidy_data)
# Out:
#   Genre         Day_Of_Week shares Popular num_keywords n_unique_tokens
# 1 entertainment monday       593   FALSE   5            0.6635945
# 2 business      monday       711   FALSE   4            0.6047431
# 3 business      monday      1500   TRUE    6            0.5751295
# 4 entertainment monday      1200   TRUE    7            0.5037879
# 5 technology    monday       505   FALSE   7            0.4156456
# 6 technology    monday       855   FALSE   9            0.5598886
# [1] 33510

# %%
options(repr.plot.width = 12, repr.plot.height = 10)
publish_plot <- tidy_data %>%
    ggplot(aes(x = Day_Of_Week, y = shares, fill = Genre)) + 
    geom_bar(stat = 'identity') +
    xlab("Day of the Week") +
    ylab("Number of Shares") +
    labs(fill = "Genre of Article") +
    theme(text = element_text(size = 20))

publish_plot
# Out:
# plot without title

# %% [markdown]
# PREDICT WHETHER A GENRE OF ARTICLE IS POPULAR OR NOT

# %%
set.seed(1234)
publishing_split <- initial_split(tidy_data, prop = 0.75, strata = shares)
publishing_train <- training(publishing_split)
publishing_test <- testing(publishing_split)

head(publishing_train)
    nrow(publishing_train)
# Out:
#   Genre         Day_Of_Week shares Popular num_keywords n_unique_tokens
# 1 entertainment monday       593   FALSE   5            0.6635945
# 2 business      monday       711   FALSE   4            0.6047431
# 3 business      monday      1500   TRUE    6            0.5751295
# 4 entertainment monday      1200   TRUE    7            0.5037879
# 5 technology    monday       505   FALSE   7            0.4156456
# 6 technology    monday       855   FALSE   9            0.5598886
# [1] 25134

# %%
knn_spec <- nearest_neighbor(weight_func = "rectangular", neighbors = tune()) %>% 
       set_engine("kknn") %>%
       set_mode("classification") 

share_recipe <- recipe(Popular ~ shares + num_keywords +n_unique_tokens, data = publishing_train) %>%
       step_scale(all_predictors()) %>%
       step_center(all_predictors())
share_recipe

shares_vfold <- vfold_cv(publishing_train, v = 5, strata = Popular)
gridvals <- tibble(neighbors = seq(1,20))
# Out:
# Data Recipe
#
# Inputs:
#
#       role #variables
#    outcome          1
#  predictor          3
#
# Operations:
#
# Scaling for all_predictors()
# Centering for all_predictors()

# %%
knn_results <- workflow() %>%
    add_recipe(share_recipe)%>%
    add_model(share_spec) %>%
    tune_grid(resamples = shares_vfold, grid = gridvals) %>%
    collect_metrics()

knn_results
# Out:
#    neighbors .metric  .estimator mean      n std_err      .config
# 1   1        accuracy binary     0.9800273 5 0.0012002573 Model01
# 2   1        roc_auc  binary     0.9780029 5 0.0016158825 Model01
# 3   2        accuracy binary     0.9800273 5 0.0012002573 Model02
# 4   2        roc_auc  binary     0.9889779 5 0.0010342061 Model02
# 5   3        accuracy binary     0.9725871 5 0.0013650318 Model03
# 6   3        roc_auc  binary     0.9937355 5 0.0006733782 Model03
# 7   4        accuracy binary     0.9725871 5 0.0013650318 Model04
# 8   4        roc_auc  binary     0.9950750 5 0.0006107714 Model04
# 9   5        accuracy binary     0.9698817 5 0.0011543058 Model05
# 10  5        roc_auc  binary     0.9956117 5 0.0004199913 Model05
# 11  6        accuracy binary     0.9698817 5 0.0011543058 Model06
# 12  6        roc_auc  binary     0.9956842 5 0.0003826319 Model06
# 13  7        accuracy binary     0.9675343 5 0.0011155179 Model07
# 14  7        roc_auc  binary     0.9955417 5 0.0003194836 Model07
# 15  8        accuracy binary     0.9675343 5 0.0011155179 Model08
# 16  8        roc_auc  binary     0.9955713 5 0.0003095309 Model08
# 17  9        accuracy binary     0.9661018 5 0.0012118625 Model09
# 18  9        roc_auc  binary     0.9953830 5 0.0003039519 Model09
# 19 10        accuracy binary     0.9661018 5 0.0012118625 Model10
# 20 10        roc_auc  binary     0.9951101 5 0.0003187871 Model10
# 21 11        accuracy binary     0.9635952 5 0.0012225721 Model11
# 22 11        roc_auc  binary     0.9948436 5 0.0003330031 Model11
# 23 12        accuracy binary     0.9635952 5 0.0012225721 Model12
# 24 12        roc_auc  binary     0.9945397 5 0.0003391005 Model12
# 25 13        accuracy binary     0.9612878 5 0.0015022774 Model13
# 26 13        roc_auc  binary     0.9942858 5 0.0003250962 Model13
# 27 14        accuracy binary     0.9612878 5 0.0015022774 Model14
# 28 14        roc_auc  binary     0.9940370 5 0.0003985162 Model14
# 29 15        accuracy binary     0.9599748 5 0.0015215050 Model15
# 30 15        roc_auc  binary     0.9937512 5 0.0004256950 Model15
# 31 16        accuracy binary     0.9599748 5 0.0015215050 Model16
# 32 16        roc_auc  binary     0.9934900 5 0.0004965119 Model16
# 33 17        accuracy binary     0.9583833 5 0.0015769610 Model17
# 34 17        roc_auc  binary     0.9932760 5 0.0005181019 Model17
# 35 18        accuracy binary     0.9583833 5 0.0015769610 Model18
# 36 18        roc_auc  binary     0.9929482 5 0.0005606258 Model18
# 37 19        accuracy binary     0.9557176 5 0.0012957843 Model19
# 38 19        roc_auc  binary     0.9926367 5 0.0005941312 Model19
# 39 20        accuracy binary     0.9557574 5 0.0013184434 Model20
# 40 20        roc_auc  binary     0.9923745 5 0.0006083018 Model20

# %%
accuracies <- knn_results %>%
  filter(.metric == "accuracy")

accuracy_vs_k <- ggplot(accuracies, aes(x = neighbors, y = mean)) +
  geom_point() +
  geom_line() +
  labs(x = "Neighbors", y = "Accuracy Estimate")
accuracy_vs_k
filter(accuracies, mean ==max(mean))
# Out:
#   neighbors .metric  .estimator mean      n std_err     .config
# 1 1         accuracy binary     0.9800273 5 0.001200257 Model01
# 2 2         accuracy binary     0.9800273 5 0.001200257 Model02
# plot without title

# %%
share_spec <- nearest_neighbor(weight_func = "rectangular", neighbors = 2) %>% 
       set_engine("kknn") %>%
       set_mode("classification")

# %%
share_recipe <- recipe(Popular ~ shares + num_keywords +n_unique_tokens, data = publishing_train) %>%
       step_scale(all_predictors()) %>%
       step_center(all_predictors())
share_recipe
# Out:
# Data Recipe
#
# Inputs:
#
#       role #variables
#    outcome          1
#  predictor          3
#
# Operations:
#
# Scaling for all_predictors()
# Centering for all_predictors()

# %%
share_workflow <-workflow()%>%
    add_model(share_spec)%>%
    add_recipe(share_recipe)

share_workflow
# Out:
# ══ Workflow ════════════════════════════════════════════════════════════════════
# Preprocessor: Recipe
# Model: nearest_neighbor()
#
# ── Preprocessor ────────────────────────────────────────────────────────────────
# 2 Recipe Steps
#
# ● step_scale()
# ● step_center()
#
# ── Model ───────────────────────────────────────────────────────────────────────
# K-Nearest Neighbor Model Specification (classification)
#
# Main Arguments:
#   neighbors = 2
#   weight_func = rectangular
#
# Computational engine: kknn

# %%
share_fit <- fit(share_workflow, data = publishing_train)
share_fit
# Out:
# ══ Workflow [trained] ══════════════════════════════════════════════════════════
# Preprocessor: Recipe
# Model: nearest_neighbor()
#
# ── Preprocessor ────────────────────────────────────────────────────────────────
# 2 Recipe Steps
#
# ● step_scale()
# ● step_center()
#
# ── Model ───────────────────────────────────────────────────────────────────────
#
# Call:
# kknn::train.kknn(formula = ..y ~ ., data = data, ks = ~2, kernel = ~"rectangular")
#
# Type of response variable: nominal
# Minimal misclassification: 0.02606032
# Best kernel: rectangular
# Best k: 2

# %%
share_test_predictions <- predict(share_fit, publishing_test) %>%
  bind_cols(publishing_test)
share_test_predictions
# Out:
#      .pred_class Genre         Day_Of_Week shares Popular num_keywords
# 1    TRUE        technology    monday       3600  TRUE     7
# 2    FALSE       technology    monday        783  FALSE   10
# 3    FALSE       business      monday        425  FALSE    6
# 4    FALSE       lifestyle     monday        343  FALSE   10
# 5    FALSE       world         monday        504  FALSE    6
# 6    TRUE        technology    monday       1500  TRUE     8
# 7    FALSE       lifestyle     monday        507  FALSE    8
# 8    TRUE        technology    monday       1200  TRUE     8
# 9    TRUE        technology    monday       4900  TRUE    10
# 10   FALSE       business      monday        819  FALSE   10
# 11   FALSE       technology    monday        645  FALSE    7
# 12   TRUE        technology    monday       3200  TRUE     8
# 13   FALSE       technology    monday        545  FALSE    9
# 14   TRUE        technology    monday       2800  TRUE    10
# 15   FALSE       world         monday        495  FALSE    6
# 16   TRUE        technology    monday       1300  TRUE     8
# 17   FALSE       entertainment monday        631  FALSE   10
# 18   FALSE       world         tuesday       468  FALSE    6
# 19   FALSE       technology    tuesday       500  FALSE    7
# 20   FALSE       entertainment wednesday     455  FALSE    6
# 21   FALSE       business      wednesday     459  FALSE    6
# 22   TRUE        entertainment wednesday    6400  TRUE     5
# 23   FALSE       world         wednesday     971  FALSE    6
# 24   TRUE        lifestyle     wednesday    1900  TRUE     6
# 25   TRUE        entertainment wednesday    1500  TRUE     6
# 26   TRUE        entertainment wednesday   19400  TRUE    10
# 27   FALSE       business      wednesday     474  FALSE    6
# 28   TRUE        entertainment wednesday    2100  TRUE     4
# 29   TRUE        technology    wednesday    5600  TRUE     8
# 30   TRUE        technology    wednesday    1200  TRUE     6
# ⋮    ⋮           ⋮             ⋮           ⋮      ⋮       ⋮
# 8347 TRUE        technology    monday       1300  TRUE     5
# 8348 TRUE        world         monday       1400  TRUE     7
# 8349 FALSE       world         monday        749  FALSE    6
# 8350 TRUE        technology    monday      16800  TRUE     7
# 8351 TRUE        world         monday       2000  TRUE     6
# 8352 TRUE        entertainment monday       1300  TRUE     6
# 8353 TRUE        world         monday       1200  TRUE     7
# 8354 TRUE        business      monday       3400  TRUE     7
# 8355 TRUE        lifestyle     monday       1500  TRUE     6
# 8356 TRUE        entertainment monday       1100  TRUE    10
# 8357 FALSE       business      monday        984  FALSE    4
# 8358 TRUE        world         monday       1100  TRUE     7
# 8359 FALSE       world         tuesday      1000  FALSE    7
# 8360 TRUE        entertainment tuesday      2600  TRUE     7
# 8361 TRUE        world         tuesday      6000  TRUE     6
# 8362 TRUE        lifestyle     tuesday      1300  TRUE     9
# 8363 FALSE       lifestyle     tuesday       778  FALSE    5
# 8364 TRUE        entertainment tuesday      1300  TRUE     6
# 8365 TRUE        lifestyle     tuesday      1300  TRUE     7
# 8366 FALSE       world         tuesday       706  FALSE    6
# 8367 TRUE        technology    tuesday      1500  TRUE     7
# 8368 TRUE        world         tuesday      1400  TRUE     9
# 8369 TRUE        world         tuesday      2400  TRUE     9
# 8370 TRUE        technology    tuesday      3200  TRUE     7
# 8371 FALSE       world         tuesday      1000  FALSE    5
# 8372 TRUE        world         tuesday      1500  TRUE    10
# 8373 TRUE        world         tuesday      1500  TRUE     6
# 8374 TRUE        entertainment wednesday    1400  TRUE     8
# 8375 TRUE        technology    wednesday    1800  TRUE     8
# 8376 TRUE        entertainment wednesday    1300  TRUE     4
#      Unpopular n_unique_tokens
# 1    FALSE     0.6701031
# 2    TRUE      0.5725806
# 3    TRUE      0.4909344
# 4    TRUE      0.5512820
# 5    TRUE      0.5043915
# 6    FALSE     0.4274274
# 7    TRUE      0.4087031
# 8    FALSE     0.4186916
# 9    FALSE     0.6445498
# 10   TRUE      0.6009174
# 11   TRUE      0.4215501
# 12   FALSE     0.5160428
# 13   TRUE      0.6157025
# 14   FALSE     0.5000000
# 15   TRUE      0.4671202
# 16   FALSE     0.4279835
# 17   TRUE      0.6182336
# 18   TRUE      0.6067961
# 19   TRUE      0.4138973
# 20   TRUE      0.6064356
# 21   TRUE      0.4986667
# 22   FALSE     0.6595745
# 23   TRUE      0.5349794
# 24   FALSE     0.6621622
# 25   FALSE     0.5466667
# 26   FALSE     0.6275304
# 27   TRUE      0.5525672
# 28   FALSE     0.6036585
# 29   FALSE     0.5316901
# 30   FALSE     0.4418605
# ⋮    ⋮         ⋮
# 8347 FALSE     0.4994675
# 8348 FALSE     0.5617647
# 8349 TRUE      0.4055046
# 8350 FALSE     0.5095949
# 8351 FALSE     0.6118421
# 8352 FALSE     0.4432314
# 8353 FALSE     0.5513834
# 8354 FALSE     0.5657370
# 8355 FALSE     0.4555556
# 8356 FALSE     0.5594059
# 8357 TRUE      0.5794872
# 8358 FALSE     0.4097487
# 8359 FALSE     0.4615385
# 8360 FALSE     0.5859031
# 8361 FALSE     0.5731707
# 8362 FALSE     0.5943775
# 8363 TRUE      0.5108878
# 8364 FALSE     0.5582418
# 8365 FALSE     0.5304659
# 8366 TRUE      0.5475638
# 8367 FALSE     0.5400000
# 8368 FALSE     0.5174538
# 8369 FALSE     0.5566751
# 8370 FALSE     0.5149254
# 8371 FALSE     0.5525040
# 8372 FALSE     0.4541667
# 8373 FALSE     0.4760331
# 8374 FALSE     0.4257106
# 8375 FALSE     0.5290520
# 8376 FALSE     0.7019868

# %%
share_test_predictions %>%
  metrics(truth = Popular, estimate = .pred_class)
# Out:
#   .metric  .estimator .estimate
# 1 accuracy binary     0.9866285
# 2 kap      binary     0.9697831

# %%
popular_to_unpopular_ratio <- publishing_train%>%
    group_by(Popular)%>%
    summarize(count = n())
popular_to_unpopular_ratio
# Out:
# `summarise()` ungrouping output (override with `.groups` argument)
#   Popular count
# 1 FALSE    8196
# 2 TRUE    16938

# %%
options(repr.plot.width = 20, repr.plot.height = 20)


share_plot <- ggplot(share_test_predictions, aes(x = reorder(Genre, shares), y = shares, fill = Popular)) +
    geom_bar(stat = "identity") +
    labs(x = "Genre", y = "Shares",  fill = "Popular") +
    theme(text = element_text(size = 18))+
    coord_flip()
share_plot
# Out:
# plot without title

# %%
options(repr.plot.width = 15, repr.plot.height = 10)
share_plot_scatter <- ggplot(share_test_predictions, aes(x = Genre, y = shares, color = Popular)) +
    geom_point() +
    labs(x = "Genre", y = "Shares",  fill = "Popular") +
    theme(text = element_text(size = 18))
share_plot_scatter
# Out:
# plot without title
